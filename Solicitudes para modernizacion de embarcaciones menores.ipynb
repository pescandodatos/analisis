# %%
# %matplotlib inline

import pandas

solicitudes = pandas.read_csv('datos/solicitudes_embarcaciones_menores.csv')
# Out:
#     Componente   Año           Estado       Municipio             Localidad  \
# 0        MOTOR  2014   AGUASCALIENTES  AGUASCALIENTES        AGUASCALIENTES
# 1  EMBARCACION  2014   AGUASCALIENTES  AGUASCALIENTES        AGUASCALIENTES
# 2      HIELERA  2014   AGUASCALIENTES  AGUASCALIENTES        AGUASCALIENTES
# 3      SISTEMA  2014   AGUASCALIENTES  AGUASCALIENTES        AGUASCALIENTES
# 4        MOTOR  2014  BAJA CALIFORNIA        ENSENADA  BAHIA DE LOS ANGELES
#
#    Registradas  Apoyadas
# 0          NaN         0
# 1          1.0         0
# 2          0.0         0
# 3          0.0         0
# 4          3.0         1

# %%
sol_proc = solicitudes[['Año', 'Registradas', 'Apoyadas']].groupby(['Año']).sum()

sol_proc['porcentaje'] = sol_proc['Apoyadas']*100/sol_proc['Registradas']

sol_proc.plot.pie(y='Año')

# Solicitudes recibidas, procesadas y porcentaje de solicitudes atendidas por año por estado
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-699258aee057> in <module>()
#       3 sol_proc['porcentaje'] = sol_proc['Apoyadas']*100/sol_proc['Registradas']
#       4
# ----> 5 sol_proc.plot.pie(y='Año')
#       6
#       7 # Solicitudes recibidas, procesadas y porcentaje de solicitudes atendidas por año por estado
#
# /Users/gaba/Code/engineroom/analisis/.env/lib/python2.7/site-packages/pandas/plotting/_core.pyc in pie(self, y, **kwds)
#    2770         axes : matplotlib.AxesSubplot or np.array of them
#    2771         """
# -> 2772         return self(kind='pie', y=y, **kwds)
#    2773
#    2774     def scatter(self, x, y, s=None, c=None, **kwds):
#
# ...

# %%
solicitudes[['Año', 'Estado','Registradas', 'Apoyadas']].groupby(['Año', 'Estado']).sum()

# Solicitudes recibidas y procesadas por año por estado
# Out:
#                            Registradas  Apoyadas
# Año  Estado
# 2014 AGUASCALIENTES       1.000000e+00         0
#      BAJA CALIFORNIA      4.070000e+02       132
#      BAJA CALIFORNIA SUR  6.790000e+02       118
#      CAMPECHE             1.395000e+03       127
#      CHIAPAS              2.130000e+02        63
#      COAHUILA             2.900000e+01        20
#      COLIMA               1.190000e+02        93
#      DURANGO              5.600000e+01        21
#      GUANAJUATO           8.700000e+01         0
#      GUERRERO             8.500000e+02       422
#      HIDALGO              3.700000e+01        37
#      JALISCO              1.001000e+03       210
#      MICHOACAN            5.650000e+02       431
#      MORELOS              1.800000e+01        18
#      NAYARIT              1.910000e+02         0
#      OAXACA               3.420000e+02       195
#      QUERETARO            2.500000e+01        18
#      QUINTANA ROO         3.790000e+02         0
# ...

# %%
solicitudes[['Componente', 'Registradas', 'Apoyadas']].groupby('Componente').sum()
# Out:
#               Registradas  Apoyadas
# Componente
# EMBARCACION  1.209100e+04      1685
# HIELERA      4.364000e+03       203
# MOTOR        1.000393e+10      3651
# SISTEMA      1.151500e+04       348
